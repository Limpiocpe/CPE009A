# %% [markdown]
# <a href="https://colab.research.google.com/github/Limpiocpe/CPE009A/blob/main/March%2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Car:
    car_type = "Sedan"
    def __init__(self, name, mileage):
        self.name = name
        self.mileage = mileage
    def description(self):
        return "The {self.name} car gives the mileage of {self.mileage}km/l"
    def max_speed(self, speed):
        return "The {self.name} runs at the maximum speed of {speed}km/hr"

# %%
class Car:
  def __init__(self, name, mileage):
    self.name = name
    self.mileage = mileage
obj1 = Car("Toyota", 2202)
obj2 = Car("Subaru", 1200)
print(obj1.name)
print(obj1.mileage, "km/1")
print(obj2.name)
print(obj2.mileage, "km/l")
# Out:
# Toyota
# 2202 km/1
# Subaru
# 1200 km/l

# %%
class Car:
  def __init__(self, name, mileage):
    self.name = name
    self.mileage = mileage
obj1 = Car("Toyota", 2202)
obj2 = Car("Subaru", 1200)
print(obj1.name,obj1.mileage)
print(obj2.name,obj2.mileage)
def description(self):
  return f"The {self.name} car gives the mileage of {self.mileage}km/1"
print(description(obj1))
print(description(obj2))
# Out:
# Toyota 2202
# Subaru 1200
# The Toyota car gives the mileage of 2202km/1
# The Subaru car gives the mileage of 1200km/1

# %%
class Car:
  def __init__(self, name, speed):
    self.name = name
    self.speed = speed
obj1 = Car("Bugatti",320)
obj2 = Car("Subaru", 210)
print(obj1.name)
print(obj1.speed, "km/hr")
print(obj2.name)
print(obj2.speed, "km/hr")
# Out:
# Bugatti
# 320 km/hr
# Subaru
# 210 km/hr

# %%
class Car:
  def __init__(self, name, speed):
    self.name = name
    self.speed = speed
obj1 = Car("Bugatti",320)
obj2 = Car("Subaru", 210)
print(obj1.name, obj1.speed)
print(obj2.name, obj2.speed)
def max_speed (self, speed):
  return f"The {self.name} runs at the maximum speed of {speed}km/hr"
print(max_speed(obj1,320))
print(max_speed(obj2,210))
# Out:
# Bugatti 320
# Subaru 210
# The Bugatti runs at the maximum speed of 320km/hr
# The Subaru runs at the maximum speed of 210km/hr

# %%
import math
class Shape:
    def __init__(self, name, sides):
        self.name = name
        self.sides = sides

    def display_info(self):
        print(f"Shape: {self.name}")
        print(f"Number of sides: {self.sides}")

    def area(self):
        return 0

class Triangle(Shape):
    def __init__(self, base, height):
        super().__init__("Triangle", 3)
        self.base = base
        self.height = height

    def area(self):
        return 0.5 * self.base * self.height

class Circle(Shape):
    def __init__(self, radius):
        super().__init__("Circle", 0)
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

class Square(Shape):
    def __init__(self, side):
        super().__init__("Square", 4)
        self.side = side

    def area(self):
        return self.side ** 2


class Rectangle(Shape):
    def __init__(self, length, width):
        super().__init__("Rectangle", 4)
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width
