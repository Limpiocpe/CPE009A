# %% [markdown]
# <a href="https://colab.research.google.com/github/Limpiocpe/CPE009A/blob/main/Control_Structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **If Statement**

# %%
a = 12
b = 100
if b > a:
    print("b is greater than a")
# Out:
# b is greater than a

# %% [markdown]
# **Elif Statements**

# %%
a = 12
b = 12
if b > a:
    print("b is greater than a")
elif a == b:
    print("a and b are equal")

# %% [markdown]
# **Else Statements**

# %%
a = 200
b = 33
if b > a:
    print("b is greater than a")
elif a == b:
    print("a and b are equal")
else:
    print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# **Short Hand If Statement**

# %%
a = 200
b = 33
if a>b: print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# **Short Hand If..Else Statement**

# %%
a = 2
b = 330
print("A") if a > b else print("B")
# Out:
# B

# %% [markdown]
# **And-both conditions are true**

# %%
a = 200
b = 33
c = 500

if a > b and c > a:
    print("Both conditions are True")
# Out:
# Both conditions are True

# %% [markdown]
# **Or-at least one of the conditions is true**

# %%
a = 200
b = 33
c = 500
if a > b or a > c:
    print("At least one of the conditions is True")
# Out:
# At least one of the conditions is True

# %% [markdown]
# **Nested if**

# %%
#Create a python program that will display above 10, above 20, above 30,  above 40:
# +5 Points
x = 41
if x > 10:
  print("Above ten, ")
  if x > 20:
    print("and also above 20!")
    if x > 30:
        print("and also above 30!")
        if x > 40:
          print("and also above 40!")
          if x > 50:
            print("and also above 50!")
          else:
            print("but not above 50.")
        else:
          print("but not above 40.")
    else:
      print("but not above 30.")
  else:
    print("but not above 20.")
# Out:
# Above ten,
# and also above 20!
# and also above 30!
# and also above 40!
# It is 41
# but not above 50.

# %% [markdown]
# **Supplementary**

# %% [markdown]
# Example 1

# %%
#Write a program that determines if you are qualified to vote.
age = int(input())
if age >= 18:
  print("You are qualified to vote.")
else:
  print("You are not qualified to vote.")
# Out:
# 19
# You are qualified to vote.

# %% [markdown]
# Example 2

# %%
#Write a program to determine if the input is positive, negative or zero
num = int(input())
if num > 0:
  print("The number is Positive.")
  if num == 0:
    print("The number is Zero.")
else:
  print("The number is Negative.")
# Out:
# 12
# The number is Positive

# %% [markdown]
# Example 3

# %%
#Write a program to ddetermine if the grade is passing, failed or remedial
# +5 Points
grade = int(input("Please enter your grade: "))
if grade > 74:
  print("Passed")
elif grade == 74:
  print("Remedial")
else:
  print("Failed")
# Out:
# Please enter your grade: 73
# Failed
