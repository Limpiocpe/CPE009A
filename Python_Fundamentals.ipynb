# %% [markdown]
# <a href="https://colab.research.google.com/github/Limpiocpe/CPE009A/blob/main/Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Indentation

# %%
if 5 > 2:
  print("Five is greater than two!")
# Out:
# Five is greater than two!

# %% [markdown]
# Python Comments

# %%
#This is a comment
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# Variable Naming Conventions

# %%
myvar = 5
print(myvar)
# Out:
# 5

# %% [markdown]
# Python Variable

# %%
x = 1
a, b = 0, -1
a, b, c = 0, -1, 2

b = "Sally" #This is a type of string
print(b)
# Out:
# Sally
