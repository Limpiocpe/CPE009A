# %% [markdown]
# <a href="https://colab.research.google.com/github/Limpiocpe/CPE009A/blob/main/Laboratory_Activity_1_Literals%2C_Operators%2C_and_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Assigning variables of different data types in Python**

# %% [markdown]
# Step 1

# %%
value = 5
print(value)
# Out:
# 5

# %% [markdown]
# Step 2

# %%
type(value)
# Out:
# int

# %% [markdown]
# Step 3

# %%
value = 5.0
print(value)
type(value)
# Out:
# 5.0
# float

# %% [markdown]
# Step 4

# %%
value = 2+3j
print(value)
type(value)
# Out:
# (2+3j)
# complex

# %%
value = 'Hello World'
print(value)
type(value)
# Out:
# Hello World
# str

# %%
value = "Hello World"
print(value)
type(value)
# Out:
# Hello World
# str

# %%
value = True
print(value)
type(value)
# Out:
# True
# bool

# %%
value = False
print(value)
type(value)
# Out:
# False
# bool

# %%
value = [1, 2, 3, 4, 5]
print(value)
type(value)
# Out:
# [1, 2, 3, 4, 5]
# list

# %%
value = (1, 2, 3, 4, 5)
print(value)
type(value)
# Out:
# (1, 2, 3, 4, 5)
# tuple

# %%
value = {'name': 'Ramelissa'}
print(value)
type(value)
# Out:
# {'name': 'Ramelissa'}
# dict

# %%
value = None
print(value)
type(value)
# Out:
# None
# NoneType

# %% [markdown]
# Step 6

# %%
value = 5
print(value)
type(value)
# Out:
# 5

# %% [markdown]
# Step 7

# %%
value2 = -6

# %% [markdown]
# **Performing Operations with Python**

# %% [markdown]
# Step 1

# %%
print(value+value2)
# Out:
# -1

# %% [markdown]
# Step 2

# %%
value, value2 = 5.0, 6
print(value+value2)
print(value-value2)
# Out:
# 11.0
# -1.0

# %%
value, value2 = -5, 6.1
print(value+value2)
print(value-value2)
# Out:
# 1.0999999999999996
# -11.1

# %%
value, value2 = "Hello", 'world'
print(value+value2)
# Out:
# Helloworld

# %%
value, value2 = [1,2,3], [4,5,6]
print(value+value2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
value, value2 = (1,2,3), (4,5,6)
print(value+value2)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
value, value2 = {"name":"Royce"}, {"age": 2}
print(value | value2)
# Out:
# {'name': 'Royce', 'age': 2}

# %% [markdown]
# Step 3

# %%
value, value2 = 30, 4

# %%
print(value * value2)
# Out:
# 120

# %%
print(value2 ** 2)
# Out:
# 16

# %%
print(value2 ** 3)
# Out:
# 64

# %%
print(value * value2 + value2 ** 2 + 1)
# Out:
# 137

# %%
print(value / value2)
# Out:
# 7.5

# %%
print(value % value2)
# Out:
# 2

# %% [markdown]
# **Receiving input Data using Python**

# %%
input("Message Name ")
# Out:
# Message namehello
# 'hello'

# %%
name = input("Enter your name: ")
print(name)
# Out:
# Enter your name: Ramelissa
# Ramelissa

# %% [markdown]
# **Assigning Input Data to a Variable**

# %%
name = input("Enter your name ")
weight = float(input("Enter your weight "))
height = float(input("Enter your height "))
bmi = weight / height ** 2

print("Name: ", name)
print("Weight: ", weight)
print("Height: ", height)
print("BMI = ", bmi)
#
# Out:
# Enter your name John Ray
# Enter your weight 60
# Enter your height 1.6764
# Name:  John Ray
# Weight:  60.0
# Height:  1.6764
# BMI =  21.349904958763087

# %% [markdown]
# **Supplementary Activity**

# %% [markdown]
# Task 1

# %%
base = float(input("Enter the base of the triangle: "))
height = float(input("Enter the height of the triangle: "))
area = 0.5 * base * height
print("The area of the triangle is: ", area)
# Out:
# Enter the base of the triangle: 5
# Enter the height of the triangle: 5
# The area of the triangle is:  12.5

# %% [markdown]
# Task 2

# %%
celsius = input("Enter the temperature in Celsius: ")
fahrenheit = (float(celsius) * 9/5) + 32
print(celsius, "°C =", fahrenheit, "°F"  )
# Out:
# Enter the temperature in Celsius: 0
# 0 °C = 32.0 °F

# %% [markdown]
# Task 3

# %%
x1 = float(input("x1: "))
y1 = float(input("y1: "))
x2 = float(input("x2: "))
y2 = float(input("y2: "))
d = ((x2 - x1)**2 + (y2 - y1)**2)** 0.5
print(d)
# Out:
# x1: 2
# y1: 2
# x2: -3
# y2: 3
# 5.0990195135927845
